# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# !pip install dataframe_image
import dataframe_image as dfi
# Out:
# Requirement already satisfied: dataframe_image in e:\aanconda\envs\dev\lib\site-packages (0.1.11)
# Requirement already satisfied: packaging in e:\aanconda\envs\dev\lib\site-packages (from dataframe_image) (23.0)
# Requirement already satisfied: pillow in e:\aanconda\envs\dev\lib\site-packages (from dataframe_image) (9.4.0)
# Requirement already satisfied: nbconvert>=5 in e:\aanconda\envs\dev\lib\site-packages (from dataframe_image) (6.5.4)
# Requirement already satisfied: mistune in e:\aanconda\envs\dev\lib\site-packages (from dataframe_image) (0.8.4)
# Requirement already satisfied: lxml in e:\aanconda\envs\dev\lib\site-packages (from dataframe_image) (4.9.2)
# Requirement already satisfied: html2image in e:\aanconda\envs\dev\lib\site-packages (from dataframe_image) (2.0.3)
# Requirement already satisfied: pandas>=0.24 in e:\aanconda\envs\dev\lib\site-packages (from dataframe_image) (1.5.3)
# Requirement already satisfied: cssutils in e:\aanconda\envs\dev\lib\site-packages (from dataframe_image) (2.7.1)
# Requirement already satisfied: aiohttp in e:\aanconda\envs\dev\lib\site-packages (from dataframe_image) (3.8.3)
# Requirement already satisfied: requests in e:\aanconda\envs\dev\lib\site-packages (from dataframe_image) (2.29.0)
# Requirement already satisfied: beautifulsoup4 in e:\aanconda\envs\dev\lib\site-packages (from dataframe_image) (4.12.2)
# Requirement already satisfied: defusedxml in e:\aanconda\envs\dev\lib\site-packages (from nbconvert>=5->dataframe_image) (0.7.1)
# Requirement already satisfied: pygments>=2.4.1 in e:\aanconda\envs\dev\lib\site-packages (from nbconvert>=5->dataframe_image) (2.15.1)
# Requirement already satisfied: entrypoints>=0.2.2 in e:\aanconda\envs\dev\lib\site-packages (from nbconvert>=5->dataframe_image) (0.4)
# Requirement already satisfied: bleach in e:\aanconda\envs\dev\lib\site-packages (from nbconvert>=5->dataframe_image) (4.1.0)
# Requirement already satisfied: jinja2>=3.0 in e:\aanconda\envs\dev\lib\site-packages (from nbconvert>=5->dataframe_image) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in e:\aanconda\envs\dev\lib\site-packages (from nbconvert>=5->dataframe_image) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in e:\aanconda\envs\dev\lib\site-packages (from nbconvert>=5->dataframe_image) (5.7.0)
# Requirement already satisfied: tinycss2 in e:\aanconda\envs\dev\lib\site-packages (from nbconvert>=5->dataframe_image) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in e:\aanconda\envs\dev\lib\site-packages (from nbconvert>=5->dataframe_image) (0.1.2)
# Requirement already satisfied: jupyter-core>=4.7 in e:\aanconda\envs\dev\lib\site-packages (from nbconvert>=5->dataframe_image) (5.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\aanconda\envs\dev\lib\site-packages (from nbconvert>=5->dataframe_image) (2.1.1)
# Requirement already satisfied: traitlets>=5.0 in e:\aanconda\envs\dev\lib\site-packages (from nbconvert>=5->dataframe_image) (5.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in e:\aanconda\envs\dev\lib\site-packages (from nbconvert>=5->dataframe_image) (1.5.0)
# Requirement already satisfied: numpy>=1.21.0 in e:\aanconda\envs\dev\lib\site-packages (from pandas>=0.24->dataframe_image) (1.24.3)
# Requirement already satisfied: pytz>=2020.1 in e:\aanconda\envs\dev\lib\site-packages (from pandas>=0.24->dataframe_image) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in e:\aanconda\envs\dev\lib\site-packages (from pandas>=0.24->dataframe_image) (2.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in e:\aanconda\envs\dev\lib\site-packages (from aiohttp->dataframe_image) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\aanconda\envs\dev\lib\site-packages (from aiohttp->dataframe_image) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\aanconda\envs\dev\lib\site-packages (from aiohttp->dataframe_image) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in e:\aanconda\envs\dev\lib\site-packages (from aiohttp->dataframe_image) (1.8.1)
# Requirement already satisfied: aiosignal>=1.1.2 in e:\aanconda\envs\dev\lib\site-packages (from aiohttp->dataframe_image) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in e:\aanconda\envs\dev\lib\site-packages (from aiohttp->dataframe_image) (2.0.4)
# Requirement already satisfied: attrs>=17.3.0 in e:\aanconda\envs\dev\lib\site-packages (from aiohttp->dataframe_image) (22.1.0)
# Requirement already satisfied: soupsieve>1.2 in e:\aanconda\envs\dev\lib\site-packages (from beautifulsoup4->dataframe_image) (2.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\aanconda\envs\dev\lib\site-packages (from requests->dataframe_image) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in e:\aanconda\envs\dev\lib\site-packages (from requests->dataframe_image) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in e:\aanconda\envs\dev\lib\site-packages (from requests->dataframe_image) (1.26.15)
# Requirement already satisfied: pywin32>=300 in e:\aanconda\envs\dev\lib\site-packages (from jupyter-core>=4.7->nbconvert>=5->dataframe_image) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in e:\aanconda\envs\dev\lib\site-packages (from jupyter-core>=4.7->nbconvert>=5->dataframe_image) (2.5.2)
# Requirement already satisfied: jupyter-client>=6.1.5 in e:\aanconda\envs\dev\lib\site-packages (from nbclient>=0.5.0->nbconvert>=5->dataframe_image) (8.1.0)
# Requirement already satisfied: nest-asyncio in e:\aanconda\envs\dev\lib\site-packages (from nbclient>=0.5.0->nbconvert>=5->dataframe_image) (1.5.6)
# Requirement already satisfied: jsonschema>=2.6 in e:\aanconda\envs\dev\lib\site-packages (from nbformat>=5.1->nbconvert>=5->dataframe_image) (4.17.3)
# Requirement already satisfied: fastjsonschema in e:\aanconda\envs\dev\lib\site-packages (from nbformat>=5.1->nbconvert>=5->dataframe_image) (2.16.2)
# Requirement already satisfied: six>=1.5 in e:\aanconda\envs\dev\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24->dataframe_image) (1.16.0)
# Requirement already satisfied: webencodings in e:\aanconda\envs\dev\lib\site-packages (from bleach->nbconvert>=5->dataframe_image) (0.5.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in e:\aanconda\envs\dev\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=5->dataframe_image) (0.18.0)
# Requirement already satisfied: tornado>=6.2 in e:\aanconda\envs\dev\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert>=5->dataframe_image) (6.2)
# Requirement already satisfied: pyzmq>=23.0 in e:\aanconda\envs\dev\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert>=5->dataframe_image) (25.0.2)

# %%
from pathlib import Path

game_sales = Path("Video_Games.csv")
game_sales_df = pd.read_csv(game_sales)
game_sales_df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
game_sales_df = game_sales_df[game_sales_df['Global_Sales'] >= 1]
game_sales_df
# Out:
#                                     Name Platform  Year_of_Release  \
# 0                             Wii Sports      Wii           2006.0
# 1                      Super Mario Bros.      NES           1985.0
# 2                         Mario Kart Wii      Wii           2008.0
# 3                      Wii Sports Resort      Wii           2009.0
# 4               Pokemon Red/Pokemon Blue       GB           1996.0
# ...                                  ...      ...              ...
# 2071                    NFL GameDay 2001       PS           2000.0
# 2072                         NBA Live 97       PS           1996.0
# 2073  Dynasty Warriors 3: Xtreme Legends      PS2           2002.0
# 2074                      Rayman Origins      PS3           2011.0
# 2075                 Jampack Winter 2000       PS           2000.0
#
#              Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0           Sports                     Nintendo     41.36     28.96      3.77
# 1         Platform                     Nintendo     29.08      3.58      6.81
# 2           Racing                     Nintendo     15.68     12.76      3.79
# 3           Sports                     Nintendo     15.61     10.93      3.28
# 4     Role-Playing                     Nintendo     11.27      8.89     10.22
# ...            ...                          ...       ...       ...       ...
# 2071        Sports  Sony Computer Entertainment      0.56      0.38      0.00
# 2072        Sports              Electronic Arts      0.55      0.38      0.00
# 2073        Action                   Tecmo Koei      0.13      0.10      0.74
# 2074      Platform                      Ubisoft      0.33      0.49      0.01
# 2075          Misc  Sony Computer Entertainment      0.55      0.38      0.00
#
#       Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# 0            8.45         82.53          76.0          51.0          8
# 1            0.77         40.24           NaN           NaN        NaN
# 2            3.29         35.52          82.0          73.0        8.3
# 3            2.95         32.77          80.0          73.0          8
# 4            1.00         31.37           NaN           NaN        NaN
# ...           ...           ...           ...           ...        ...
# 2071         0.07          1.00          73.0          10.0        tbd
# 2072         0.07          1.00           NaN           NaN        NaN
# 2073         0.03          1.00          72.0          16.0        9.3
# 2074         0.17          1.00          87.0          43.0        8.4
# 2075         0.07          1.00           NaN           NaN        NaN
#
#       User_Count           Developer Rating
# 0          322.0            Nintendo      E
# 1            NaN                 NaN    NaN
# 2          709.0            Nintendo      E
# 3          192.0            Nintendo      E
# 4            NaN                 NaN    NaN
# ...          ...                 ...    ...
# 2071         NaN          989 Sports      E
# 2072         NaN                 NaN    NaN
# 2073        54.0         Omega Force      T
# 2074       238.0  UBlart Montpellier   E10+
# 2075         NaN                 NaN    NaN
#
# [2076 rows x 16 columns]

# %%
# Remove all rows with Nan values
cleaned_game_sales_df = game_sales_df.dropna()
cleaned_game_sales_df
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 0                             Wii Sports      Wii           2006.0    Sports
# 2                         Mario Kart Wii      Wii           2008.0    Racing
# 3                      Wii Sports Resort      Wii           2009.0    Sports
# 6                  New Super Mario Bros.       DS           2006.0  Platform
# 7                               Wii Play      Wii           2006.0      Misc
# ...                                  ...      ...              ...       ...
# 2059                 NERF N-Strike Elite      Wii           2009.0   Shooter
# 2060         God of War: Ghost of Sparta      PSP           2010.0    Action
# 2067                      SoulCalibur II       XB           2003.0  Fighting
# 2073  Dynasty Warriors 3: Xtreme Legends      PS2           2002.0    Action
# 2074                      Rayman Origins      PS3           2011.0  Platform
#
#                         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                        Nintendo     41.36     28.96      3.77         8.45
# 2                        Nintendo     15.68     12.76      3.79         3.29
# 3                        Nintendo     15.61     10.93      3.28         2.95
# 6                        Nintendo     11.28      9.14      6.50         2.88
# 7                        Nintendo     13.96      9.18      2.93         2.84
# ...                           ...       ...       ...       ...          ...
# 2059              Electronic Arts      0.93      0.00      0.00         0.07
# 2060  Sony Computer Entertainment      0.41      0.35      0.03         0.21
# 2067           Namco Bandai Games      0.78      0.18      0.03         0.00
# 2073                   Tecmo Koei      0.13      0.10      0.74         0.03
# 2074                      Ubisoft      0.33      0.49      0.01         0.17
#
#       Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 0            82.53          76.0          51.0          8       322.0
# 2            35.52          82.0          73.0        8.3       709.0
# 3            32.77          80.0          73.0          8       192.0
# 6            29.80          89.0          65.0        8.5       431.0
# 7            28.92          58.0          41.0        6.6       129.0
# ...            ...           ...           ...        ...         ...
# 2059          1.00          67.0          12.0        4.5         6.0
# 2060          1.00          86.0          73.0        8.4       255.0
# 2067          1.00          92.0          39.0        8.9        54.0
# 2073          1.00          72.0          16.0        9.3        54.0
# 2074          1.00          87.0          43.0        8.4       238.0
#
#                Developer Rating
# 0               Nintendo      E
# 2               Nintendo      E
# 3               Nintendo      E
# 6               Nintendo      E
# 7               Nintendo      E
# ...                  ...    ...
# 2059        EA Salt Lake   E10+
# 2060       Ready at Dawn      M
# 2067               Namco      T
# 2073         Omega Force      T
# 2074  UBlart Montpellier   E10+
#
# [1313 rows x 16 columns]

# %%
# Calculate total number of platforms
platform_count = cleaned_game_sales_df['Platform'].nunique()
platform_count
# Out:
# 17

# %%
# Calculate total number of publishers
publisher_count = cleaned_game_sales_df['Publisher'].nunique()
publisher_count
# Out:
# 59

# %%
# Developer Count
developer_count = cleaned_game_sales_df['Developer'].nunique()
developer_count
# Out:
# 366

# %%
# Total number of games 
game_count = cleaned_game_sales_df['Name'].nunique()
game_count
# Out:
# 1001

# %%
# Calculate Total sales for each region
na_sales= sum(cleaned_game_sales_df['NA_Sales'])
eu_sales= sum(cleaned_game_sales_df['EU_Sales'])
jp_sales= sum(cleaned_game_sales_df['JP_Sales'])
other_sales = sum(cleaned_game_sales_df['Other_Sales'])
total_sales= na_sales + eu_sales + jp_sales + other_sales



# print(f'''
# Total number of NA sales: {na_sales}

# Total number of EU sales: {eu_sales}

# Total number of JP sales: {jp_sales}

# Total number of other sales: {other_sales}

# Total sales: {total_sales}
# ''')

total_sales_df = pd.DataFrame([
    {'Total of NA': na_sales, 
     'Total of EU': eu_sales, 
     'Total of JP': jp_sales, 
     'Total of Other': other_sales, 
     'Total Sales':total_sales}
])

dfi.export(game_sales_summary, 'Espy_images/totals_tables.png')
total_sales_df
# Out:
#    Total of NA  Total of EU  Total of JP  Total of Other  Total Sales
# 0      1819.26      1169.85       314.77          410.86      3714.74

# %%
# % NA from Total
percent_na = na_sales / total_sales
percent_na
# Out:
# 0.4897408701551121

# %%
# average critic score
avg_critic_score = cleaned_game_sales_df['Critic_Score'].mean()
avg_critic_score
# Out:
# 79.46915460776847

# %%
avg_user_score= cleaned_game_sales_df['User_Score'].astype('float64').mean()
avg_user_score
# Out:
# 7.585833968012185

# %%
# Calculate percentage of games with higher than 80% critic score
positive_critic_review_count = cleaned_game_sales_df[(cleaned_game_sales_df['Critic_Score'] >= 80)].count()["Name"]
positive_critic_game_percentage  = positive_critic_review_count / float(game_count) * 100
positive_critic_game_percentage
# Out:
# 76.52347652347652

# %%
# Calculate percentage of games with higher than 8 User score
positive_user_review_count = cleaned_game_sales_df[(cleaned_game_sales_df['User_Score'].astype('float64') >= 8)].count()["Name"]
positive_user_game_percentage  = positive_user_review_count / float(game_count) * 100
positive_user_game_percentage
# Out:
# 60.53946053946054

# %%
game_sales_summary = pd.DataFrame([
    {'Total Number of Platforms': platform_count, 
     'Total Number of Publishers': publisher_count, 
     'Total Number of Games': game_count, 
     'Total Sale From NA': na_sales, 
     'Total Sales From EU': eu_sales, 
     'Total Number of Sales From JP': jp_sales, 
     'Total Number of Sales from Other regions': other_sales, 
     'Total Sales': total_sales, 
     'Over 80% Critic Score' : positive_critic_game_percentage, 
     'Over 80% User Score': positive_user_game_percentage}
])

dfi.export(game_sales_summary, 'Espy_images/data_summary_table.png')
game_sales_summary
# Out:
#    Total Number of Platforms  Total Number of Publishers  \
# 0                         17                          59
#
#    Total Number of Games  Total Sale From NA  Total Sales From EU  \
# 0                   1001             1819.26              1169.85
#
#    Total Number of Sales From JP  Total Number of Sales from Other regions  \
# 0                         314.77                                    410.86
#
#    Total Sales  Over 80% Critic Score  Over 80% User Score
# 0      3714.74              76.523477            60.539461

# %%
# Games per Rating
per_rating_counts = cleaned_game_sales_df.groupby('Rating')['Name'].count()
per_rating_counts
# Out:
# Rating
# AO        1
# E       452
# E10+    149
# K-A       1
# M       342
# T       368
# Name: Name, dtype: int64

# %%
# Total game count per platform
per_platform_counts = cleaned_game_sales_df.groupby('Platform')['Name'].count()
per_platform_counts
# Out:
# Platform
# 3DS      24
# DC        2
# DS       80
# GBA      37
# GC       41
# PC       46
# PS       48
# PS2     262
# PS3     212
# PS4      66
# PSP      48
# PSV       5
# Wii     116
# WiiU     18
# X360    214
# XB       48
# XOne     46
# Name: Name, dtype: int64

# %%
# Total game count per genre 
per_genre_counts = cleaned_game_sales_df.groupby('Genre')['Name'].count()
per_genre_counts
# Out:
# Genre
# Action          309
# Adventure        16
# Fighting         75
# Misc             95
# Platform         94
# Puzzle           21
# Racing          116
# Role-Playing    123
# Shooter         203
# Simulation       52
# Sports          194
# Strategy         15
# Name: Name, dtype: int64

# %%
publisher_sales_df = cleaned_game_sales_df[['Publisher', 'Name', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
publisher_sales_df
# Out:
#                         Publisher                                Name  \
# 0                        Nintendo                          Wii Sports
# 2                        Nintendo                      Mario Kart Wii
# 3                        Nintendo                   Wii Sports Resort
# 6                        Nintendo               New Super Mario Bros.
# 7                        Nintendo                            Wii Play
# ...                           ...                                 ...
# 2059              Electronic Arts                 NERF N-Strike Elite
# 2060  Sony Computer Entertainment         God of War: Ghost of Sparta
# 2067           Namco Bandai Games                      SoulCalibur II
# 2073                   Tecmo Koei  Dynasty Warriors 3: Xtreme Legends
# 2074                      Ubisoft                      Rayman Origins
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0        41.36     28.96      3.77         8.45
# 2        15.68     12.76      3.79         3.29
# 3        15.61     10.93      3.28         2.95
# 6        11.28      9.14      6.50         2.88
# 7        13.96      9.18      2.93         2.84
# ...        ...       ...       ...          ...
# 2059      0.93      0.00      0.00         0.07
# 2060      0.41      0.35      0.03         0.21
# 2067      0.78      0.18      0.03         0.00
# 2073      0.13      0.10      0.74         0.03
# 2074      0.33      0.49      0.01         0.17
#
# [1313 rows x 6 columns]

# %%
# Total sales per publisher per region

publisher_sales_df = publisher_sales_df.groupby('Publisher').sum()
publisher_sales_df
# Out:
# C:\Users\Espy\AppData\Local\Temp\ipykernel_35940\2401239934.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   publisher_sales_df = publisher_sales_df.groupby('Publisher').sum()
#                                         NA_Sales  EU_Sales  JP_Sales  \
# Publisher
# 505 Games                                   8.61      5.39      0.23
# Acclaim Entertainment                       3.35      2.26      0.06
# Activision                                223.95    132.70      5.12
# Atari                                      26.36      9.68      6.34
# Atlus                                       0.36      0.23      0.38
# Bethesda Softworks                         30.09     21.99      1.19
# Black Label Games                           0.59      0.46      0.00
# Capcom                                     27.91     16.44     16.97
# City Interactive                            0.54      0.50      0.00
# Codemasters                                 1.26      4.96      0.30
# Crave Entertainment                         0.66      0.52      0.15
# D3Publisher                                 0.54      0.55      0.00
# Deep Silver                                 5.09      2.53      0.25
# Disney Interactive Studios                  8.66      4.18      0.12
# Eidos Interactive                          11.21      7.22      0.41
# Electronic Arts                           302.37    217.23      8.98
# Empire Interactive                          1.05      0.82      0.00
# GT Interactive                              3.86      3.24      0.02
# Global Star                                 1.26      0.12      0.00
# Gotham Games                                0.98      0.53      0.00
# Hasbro Interactive                          0.80      0.54      0.00
# Hello Games                                 0.63      0.76      0.03
# Infogrames                                  2.99      0.60      0.05
# Konami Digital Entertainment               25.55     28.33     14.28
# LucasArts                                  33.15     17.45      0.15
# MTV Games                                   7.02      1.88      0.01
# Mastertronic                                0.90      0.12      0.00
# Microsoft Game Studios                    121.06     49.68      2.12
# Midway Games                               12.35      5.65      0.00
# Mindscape                                   1.15      0.40      0.00
# NCSoft                                      0.96      1.07      0.00
# Namco Bandai Games                         25.63     18.19      7.89
# Nintendo                                  337.38    230.18    156.64
# Play It                                     0.52      0.40      0.00
# RTL                                         0.45      0.67      0.00
# RedOctane                                   6.40      1.28      0.03
# Russel                                      0.00      1.12      0.00
# Sega                                       36.41     27.87      4.11
# Slightly Mad Studios                        0.20      0.70      0.02
# Sony Computer Entertainment               135.55     96.20     32.45
# Sony Computer Entertainment Europe          6.23      4.66      1.45
# Sony Online Entertainment                   0.63      0.49      0.00
# SouthPeak Games                             1.00      0.04      0.00
# Square Enix                                23.91     15.05     23.83
# SquareSoft                                  7.75      3.83     11.92
# TDK Mediactive                              1.58      0.85      0.00
# THQ                                        38.66     21.86      1.69
# Take-Two Interactive                      148.87     86.54      5.21
# Tecmo Koei                                  1.65      0.71      2.83
# Tomy Corporation                            0.44      0.46      0.00
# Ubisoft                                   111.68     81.88      3.56
# Universal Interactive                       4.87      4.92      0.24
# Valve                                       0.83      0.60      0.02
# Valve Software                              1.41      0.49      0.01
# Virgin Interactive                          6.25      4.20      5.01
# Vivendi Games                              12.69      3.99      0.17
# Warner Bros. Interactive Entertainment     41.24     24.19      0.53
# Zoo Digital Publishing                      0.57      0.45      0.00
# Zoo Games                                   1.20      0.00      0.00
#
#                                         Other_Sales
# Publisher
# 505 Games                                      1.57
# Acclaim Entertainment                          0.60
# Activision                                    43.87
# Atari                                          3.39
# Atlus                                          0.15
# Bethesda Softworks                             7.49
# Black Label Games                              0.15
# Capcom                                         5.88
# City Interactive                               0.12
# Codemasters                                    1.66
# Crave Entertainment                            0.17
# D3Publisher                                    0.13
# Deep Silver                                    0.94
# Disney Interactive Studios                     1.27
# Eidos Interactive                              2.22
# Electronic Arts                               77.89
# Empire Interactive                             0.28
# GT Interactive                                 0.39
# Global Star                                    0.21
# Gotham Games                                   0.06
# Hasbro Interactive                             0.09
# Hello Games                                    0.27
# Infogrames                                     0.11
# Konami Digital Entertainment                  14.00
# LucasArts                                      7.89
# MTV Games                                      0.91
# Mastertronic                                   0.08
# Microsoft Game Studios                        14.65
# Midway Games                                   2.15
# Mindscape                                      0.15
# NCSoft                                         0.27
# Namco Bandai Games                             5.94
# Nintendo                                      59.27
# Play It                                        0.14
# RTL                                            0.12
# RedOctane                                      0.90
# Russel                                         0.00
# Sega                                           8.61
# Slightly Mad Studios                           0.16
# Sony Computer Entertainment                   43.26
# Sony Computer Entertainment Europe             1.80
# Sony Online Entertainment                      0.16
# SouthPeak Games                                0.16
# Square Enix                                    7.33
# SquareSoft                                     0.81
# TDK Mediactive                                 0.19
# THQ                                            9.40
# Take-Two Interactive                          43.74
# Tecmo Koei                                     0.32
# Tomy Corporation                               0.11
# Ubisoft                                       25.75
# Universal Interactive                          1.39
# Valve                                          0.24
# Valve Software                                 0.17
# Virgin Interactive                             1.60
# Vivendi Games                                  0.78
# Warner Bros. Interactive Entertainment         9.26
# Zoo Digital Publishing                         0.15
# Zoo Games                                      0.09

# %%
top_sales_w_nan_df = game_sales_df.sort_values(by=['Global_Sales'], ascending=False)
top_sales_w_nan_df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# 1  Nintendo     29.08      3.58      6.81         0.77         40.24
# 2  Nintendo     15.68     12.76      3.79         3.29         35.52
# 3  Nintendo     15.61     10.93      3.28         2.95         32.77
# 4  Nintendo     11.27      8.89     10.22         1.00         31.37
# 5  Nintendo     23.20      2.26      4.22         0.58         30.26
# 6  Nintendo     11.28      9.14      6.50         2.88         29.80
# 7  Nintendo     13.96      9.18      2.93         2.84         28.92
# 8  Nintendo     14.44      6.94      4.70         2.24         28.32
# 9  Nintendo     26.93      0.63      0.28         0.47         28.31
#
#    Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# 0          76.0          51.0          8       322.0  Nintendo      E
# 1           NaN           NaN        NaN         NaN       NaN    NaN
# 2          82.0          73.0        8.3       709.0  Nintendo      E
# 3          80.0          73.0          8       192.0  Nintendo      E
# 4           NaN           NaN        NaN         NaN       NaN    NaN
# 5           NaN           NaN        NaN         NaN       NaN    NaN
# 6          89.0          65.0        8.5       431.0  Nintendo      E
# 7          58.0          41.0        6.6       129.0  Nintendo      E
# 8          87.0          80.0        8.4       594.0  Nintendo      E
# 9           NaN           NaN        NaN         NaN       NaN    NaN

# %%
# Create separate pie charts for each region to visualize the distribution of sales among the top 10 games 
# in that region

top_10_na = top_sales_w_nan_df.nlargest(10, 'NA_Sales')
top_10_eu = top_sales_w_nan_df.nlargest(10, 'EU_Sales')
top_10_jp = top_sales_w_nan_df.nlargest(10, 'JP_Sales')
top_10_other = top_sales_w_nan_df.nlargest(10, 'Other_Sales')

# Function to create a pie chart for a given region
def create_pie_chart(region_df, region_name):
    plt.figure(figsize=(8, 8))
    plt.pie(region_df['Global_Sales'], labels=region_df['Name'], autopct='%1.1f%%', startangle=140)
    plt.title(f'Top 10 Games in {region_name}')
    plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is circular.
    plt.show()

# Call the function for each region
create_pie_chart(top_10_na, 'North America')
create_pie_chart(top_10_eu, 'Europe')
create_pie_chart(top_10_jp, 'Japan')
create_pie_chart(top_10_other, 'Other Regions')

# clear different gaming (based on understanding of data set, Anova comparing means )

# %%
na_sales_total = top_sales_w_nan_df['NA_Sales'].sum()
na_sales_total
# Out:
# 2793.8199999999997

# %%
top_ten_na = game_sales_df.sort_values(by=['NA_Sales'], ascending=False) 
top_ten_na.head(10)
# Out:
#                          Name Platform  Year_of_Release     Genre  \
# 0                  Wii Sports      Wii           2006.0    Sports
# 1           Super Mario Bros.      NES           1985.0  Platform
# 9                   Duck Hunt      NES           1984.0   Shooter
# 5                      Tetris       GB           1989.0    Puzzle
# 2              Mario Kart Wii      Wii           2008.0    Racing
# 3           Wii Sports Resort      Wii           2009.0    Sports
# 14         Kinect Adventures!     X360           2010.0      Misc
# 8   New Super Mario Bros. Wii      Wii           2009.0  Platform
# 7                    Wii Play      Wii           2006.0      Misc
# 18          Super Mario World     SNES           1990.0  Platform
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                 Nintendo     41.36     28.96      3.77         8.45
# 1                 Nintendo     29.08      3.58      6.81         0.77
# 9                 Nintendo     26.93      0.63      0.28         0.47
# 5                 Nintendo     23.20      2.26      4.22         0.58
# 2                 Nintendo     15.68     12.76      3.79         3.29
# 3                 Nintendo     15.61     10.93      3.28         2.95
# 14  Microsoft Game Studios     15.00      4.89      0.24         1.69
# 8                 Nintendo     14.44      6.94      4.70         2.24
# 7                 Nintendo     13.96      9.18      2.93         2.84
# 18                Nintendo     12.78      3.75      3.54         0.55
#
#     Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 0          82.53          76.0          51.0          8       322.0
# 1          40.24           NaN           NaN        NaN         NaN
# 9          28.31           NaN           NaN        NaN         NaN
# 5          30.26           NaN           NaN        NaN         NaN
# 2          35.52          82.0          73.0        8.3       709.0
# 3          32.77          80.0          73.0          8       192.0
# 14         21.81          61.0          45.0        6.3       106.0
# 8          28.32          87.0          80.0        8.4       594.0
# 7          28.92          58.0          41.0        6.6       129.0
# 18         20.61           NaN           NaN        NaN         NaN
#
#               Developer Rating
# 0              Nintendo      E
# 1                   NaN    NaN
# 9                   NaN    NaN
# 5                   NaN    NaN
# 2              Nintendo      E
# 3              Nintendo      E
# 14  Good Science Studio      E
# 8              Nintendo      E
# 7              Nintendo      E
# 18                  NaN    NaN

# %%
top_ten_eu = game_sales_df.sort_values(by=['EU_Sales'], ascending=False) 
top_ten_eu.head(10)
# Out:
#                                             Name Platform  Year_of_Release  \
# 0                                     Wii Sports      Wii           2006.0
# 2                                 Mario Kart Wii      Wii           2008.0
# 10                                    Nintendogs       DS           2005.0
# 3                              Wii Sports Resort      Wii           2009.0
# 19  Brain Age: Train Your Brain in Minutes a Day       DS           2005.0
# 7                                       Wii Play      Wii           2006.0
# 6                          New Super Mario Bros.       DS           2006.0
# 16                            Grand Theft Auto V      PS3           2013.0
# 4                       Pokemon Red/Pokemon Blue       GB           1996.0
# 15                                  Wii Fit Plus      Wii           2009.0
#
#            Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0         Sports              Nintendo     41.36     28.96      3.77
# 2         Racing              Nintendo     15.68     12.76      3.79
# 10    Simulation              Nintendo      9.05     10.95      1.93
# 3         Sports              Nintendo     15.61     10.93      3.28
# 19          Misc              Nintendo      4.74      9.20      4.16
# 7           Misc              Nintendo     13.96      9.18      2.93
# 6       Platform              Nintendo     11.28      9.14      6.50
# 16        Action  Take-Two Interactive      7.02      9.09      0.98
# 4   Role-Playing              Nintendo     11.27      8.89     10.22
# 15        Sports              Nintendo      9.01      8.49      2.53
#
#     Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# 0          8.45         82.53          76.0          51.0          8
# 2          3.29         35.52          82.0          73.0        8.3
# 10         2.74         24.67           NaN           NaN        NaN
# 3          2.95         32.77          80.0          73.0          8
# 19         2.04         20.15          77.0          58.0        7.9
# 7          2.84         28.92          58.0          41.0        6.6
# 6          2.88         29.80          89.0          65.0        8.5
# 16         3.96         21.04          97.0          50.0        8.2
# 4          1.00         31.37           NaN           NaN        NaN
# 15         1.77         21.79          80.0          33.0        7.4
#
#     User_Count       Developer Rating
# 0        322.0        Nintendo      E
# 2        709.0        Nintendo      E
# 10         NaN             NaN    NaN
# 3        192.0        Nintendo      E
# 19        50.0        Nintendo      E
# 7        129.0        Nintendo      E
# 6        431.0        Nintendo      E
# 16      3994.0  Rockstar North      M
# 4          NaN             NaN    NaN
# 15        52.0        Nintendo      E

# %%
top_ten_jp = game_sales_df.sort_values(by=['JP_Sales'], ascending=False) 
top_ten_jp.head(10)
# Out:
#                                             Name Platform  Year_of_Release  \
# 4                       Pokemon Red/Pokemon Blue       GB           1996.0
# 12                   Pokemon Gold/Pokemon Silver       GB           1999.0
# 1                              Super Mario Bros.      NES           1985.0
# 6                          New Super Mario Bros.       DS           2006.0
# 20                 Pokemon Diamond/Pokemon Pearl       DS           2006.0
# 27                   Pokemon Black/Pokemon White       DS           2010.0
# 25                 Pokemon Ruby/Pokemon Sapphire      GBA           2002.0
# 43                   Animal Crossing: Wild World       DS           2005.0
# 26   Brain Age 2: More Training in Minutes a Day       DS           2005.0
# 215                     Monster Hunter Freedom 3      PSP           2010.0
#
#             Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 4    Role-Playing  Nintendo     11.27      8.89     10.22         1.00
# 12   Role-Playing  Nintendo      9.00      6.18      7.20         0.71
# 1        Platform  Nintendo     29.08      3.58      6.81         0.77
# 6        Platform  Nintendo     11.28      9.14      6.50         2.88
# 20   Role-Playing  Nintendo      6.38      4.46      6.04         1.36
# 27   Role-Playing  Nintendo      5.51      3.17      5.65         0.80
# 25   Role-Playing  Nintendo      6.06      3.90      5.38         0.50
# 43     Simulation  Nintendo      2.50      3.45      5.33         0.86
# 26         Puzzle  Nintendo      3.43      5.35      5.32         1.18
# 215  Role-Playing    Capcom      0.00      0.00      4.87         0.00
#
#      Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 4           31.37           NaN           NaN        NaN         NaN
# 12          23.10           NaN           NaN        NaN         NaN
# 1           40.24           NaN           NaN        NaN         NaN
# 6           29.80          89.0          65.0        8.5       431.0
# 20          18.25           NaN           NaN        NaN         NaN
# 27          15.14           NaN           NaN        NaN         NaN
# 25          15.85           NaN           NaN        NaN         NaN
# 43          12.13          86.0          57.0        8.7       242.0
# 26          15.29          77.0          37.0        7.1        19.0
# 215          4.87           NaN           NaN        NaN         NaN
#
#     Developer Rating
# 4         NaN    NaN
# 12        NaN    NaN
# 1         NaN    NaN
# 6    Nintendo      E
# 20        NaN    NaN
# 27        NaN    NaN
# 25        NaN    NaN
# 43   Nintendo      E
# 26   Nintendo      E
# 215       NaN    NaN

# %%
# Looking at the top 10 games
top_sales_df = cleaned_game_sales_df.sort_values(by=['Global_Sales'], ascending=False)
top_sales_df.head(10)
# Out:
#                          Name Platform  Year_of_Release     Genre  \
# 0                  Wii Sports      Wii           2006.0    Sports
# 2              Mario Kart Wii      Wii           2008.0    Racing
# 3           Wii Sports Resort      Wii           2009.0    Sports
# 6       New Super Mario Bros.       DS           2006.0  Platform
# 7                    Wii Play      Wii           2006.0      Misc
# 8   New Super Mario Bros. Wii      Wii           2009.0  Platform
# 11              Mario Kart DS       DS           2005.0    Racing
# 13                    Wii Fit      Wii           2007.0    Sports
# 14         Kinect Adventures!     X360           2010.0      Misc
# 15               Wii Fit Plus      Wii           2009.0    Sports
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                 Nintendo     41.36     28.96      3.77         8.45
# 2                 Nintendo     15.68     12.76      3.79         3.29
# 3                 Nintendo     15.61     10.93      3.28         2.95
# 6                 Nintendo     11.28      9.14      6.50         2.88
# 7                 Nintendo     13.96      9.18      2.93         2.84
# 8                 Nintendo     14.44      6.94      4.70         2.24
# 11                Nintendo      9.71      7.47      4.13         1.90
# 13                Nintendo      8.92      8.03      3.60         2.15
# 14  Microsoft Game Studios     15.00      4.89      0.24         1.69
# 15                Nintendo      9.01      8.49      2.53         1.77
#
#     Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 0          82.53          76.0          51.0          8       322.0
# 2          35.52          82.0          73.0        8.3       709.0
# 3          32.77          80.0          73.0          8       192.0
# 6          29.80          89.0          65.0        8.5       431.0
# 7          28.92          58.0          41.0        6.6       129.0
# 8          28.32          87.0          80.0        8.4       594.0
# 11         23.21          91.0          64.0        8.6       464.0
# 13         22.70          80.0          63.0        7.7       146.0
# 14         21.81          61.0          45.0        6.3       106.0
# 15         21.79          80.0          33.0        7.4        52.0
#
#               Developer Rating
# 0              Nintendo      E
# 2              Nintendo      E
# 3              Nintendo      E
# 6              Nintendo      E
# 7              Nintendo      E
# 8              Nintendo      E
# 11             Nintendo      E
# 13             Nintendo      E
# 14  Good Science Studio      E
# 15             Nintendo      E

# %%
# Create scatter plot of Global Sales vs User Score

plt.figure(figsize=(20,15))
plt.scatter(top_sales_df['User_Score'], top_sales_df['Global_Sales'], marker='o', color='b', edgecolors='black')

# Set the plot title and axis
plt.title('Global Sales vs User Score')
plt.xlabel('User_Score')
plt.ylabel('Global Sales')


plt.show()

# %%
# Create scatter plot of Global Sales vs User Score

plt.figure(figsize=(20,15))
plt.scatter(top_sales_df['Critic_Score'], top_sales_df['Global_Sales'], marker='o', color='b', edgecolors='black')

# Set the plot title and axis
plt.title('Global Sales vs User Score')
plt.xlabel('User_Score')
plt.ylabel('Global Sales')


plt.show()

# %%
# compare sales to critic_scores platforms

# %%
# filter df to onl;y include m rated games
m_rated_df = cleaned_game_sales_df[cleaned_game_sales_df['Rating'] == 'M']

# Calculate average

# %%
# compare sales to user_score using pearson correlation and linear regression, getting r^2 value

# Calculate average Critic rating for each game rated M

avg_m_game_rating = m_rated_df.groupby('Name')['Critic_Score'].mean()

merged_m_rated_df = pd.merg()
# Out:
# Name
# 187: Ride or Die                      51.500000
# 24: The Game                          62.000000
# 25 to Life                            40.000000
# 300: March to Glory                   55.000000
# 50 Cent: Blood on the Sand            71.500000
#                                         ...
# Zone of the Enders                    78.000000
# Zone of the Enders HD Collection      74.000000
# Zone of the Enders: The 2nd Runner    82.000000
# [Prototype 2]                         76.333333
# [Prototype]                           78.500000
# Name: Critic_Score, Length: 824, dtype: float64

# %%
# categorical Enova. ex: stat difference between user score by genre. 
# difference in the means of user score by genre. 
# Do users rank genre higher than another? 
# users rate higher than another
# Evnove on genre to average user. if pvalue is low, rject null and say there is stat propability that genre 
# reject the null or fail to reject the null.

# %%
genre_counts = cleaned_game_sales_df['Genre'].value_counts()
genre_counts
# Out:
# Action          1630
# Sports           943
# Shooter          864
# Role-Playing     712
# Racing           581
# Platform         403
# Misc             384
# Fighting         378
# Simulation       297
# Strategy         267
# Adventure        248
# Puzzle           118
# Name: Genre, dtype: int64

# %%
ttl_NA_sales = game_sales_df['NA_Sales'].sum()

NA_genre_ttl_sales = game_sales_df.groupby('Genre')['NA_Sales'].sum()

NA_Genre_pert = (NA_genre_ttl_sales/ttl_NA_sales)*100

print(NA_Genre_pert.sort_values(ascending = False))

NA_pert_sales_genre = NA_Genre_pert.sort_values(ascending = False)


plt.bar(NA_pert_sales_genre.index, NA_pert_sales_genre.values, color = 'blue', alpha = 1, align = 'center')

plt.xlabel('Genre') 
plt.ylabel('Percentage of Total Sales') 
plt.title('Percentage of Total North American Sales by Genre')
plt.xticks(rotation=90)
plt.show()
# Out:
# Genre
# Action          19.965611
# Sports          15.545970
# Shooter         13.451990
# Platform        10.118975
# Misc             9.250628
# Racing           8.162185
# Role-Playing     7.513935
# Fighting         5.073343
# Simulation       4.138218
# Puzzle           2.790838
# Adventure        2.390849
# Strategy         1.557027
# Name: NA_Sales, dtype: float64

# %%
ttl_EU_sales = game_sales_df['EU_Sales'].sum()

EU_genre_ttl_sales = game_sales_df.groupby('Genre')['EU_Sales'].sum()

EU_Genre_pert = (EU_genre_ttl_sales/ttl_EU_sales)*100

print(EU_Genre_pert.sort_values(ascending = False))

EU_pert_sales_genre = EU_Genre_pert.sort_values(ascending = False)

plt.bar(EU_pert_sales_genre.index, EU_pert_sales_genre.values, color = 'red', alpha = 1, align = 'center')

plt.xlabel('Genre') 
plt.ylabel('Percentage of Total Sales') 
plt.title('Percentage of Total EU Sales by Genre')
plt.xticks(rotation=90)
plt.show()
# Out:
# Genre
# Action          21.410336
# Sports          15.539847
# Shooter         13.087967
# Racing           9.754317
# Misc             8.773977
# Platform         8.262980
# Role-Playing     7.782915
# Simulation       4.681874
# Fighting         4.137883
# Adventure        2.620563
# Puzzle           2.062549
# Strategy         1.862934
# Name: EU_Sales, dtype: float64

# %%
ttl_JP_sales = game_sales_df['JP_Sales'].sum()

JP_genre_ttl_sales = game_sales_df.groupby('Genre')['JP_Sales'].sum()

JP_Genre_pert = (JP_genre_ttl_sales/ttl_JP_sales)*100

print(JP_Genre_pert.sort_values(ascending = False))


JP_pert_sales_genre = JP_Genre_pert.sort_values(ascending = False)


plt.bar(JP_pert_sales_genre.index, JP_pert_sales_genre.values, color = 'blue', alpha = 1, align = 'center')

plt.xlabel('Genre') 
plt.ylabel('Percentage of Total Sales') 
plt.title('Percentage of Total Japanese Sales by Genre')
plt.xticks(rotation=90)
plt.show()
# Out:
# Genre
# Role-Playing    27.397239
# Action          12.443061
# Sports          10.446806
# Platform        10.083781
# Misc             8.332627
# Fighting         6.742560
# Simulation       4.917414
# Puzzle           4.417194
# Racing           4.370949
# Adventure        4.031046
# Strategy         3.827567
# Shooter          2.987444
# Name: JP_Sales, dtype: float64

# %%
Genre_salespercentage_df= pd.DataFrame({'NA_Genre_%_sales': NA_Genre_pert,
              'EU_Genre_%_sales': EU_Genre_pert,
              'JP_Genre_%_sales':JP_Genre_pert})

Genre_salespercentage_df
# Out:
#               NA_Genre_%_sales  EU_Genre_%_sales  JP_Genre_%_sales
# Genre
# Action               19.965611         21.410336         12.443061
# Adventure             2.390849          2.620563          4.031046
# Fighting              5.073343          4.137883          6.742560
# Misc                  9.250628          8.773977          8.332627
# Platform             10.118975          8.262980         10.083781
# Puzzle                2.790838          2.062549          4.417194
# Racing                8.162185          9.754317          4.370949
# Role-Playing          7.513935          7.782915         27.397239
# Shooter              13.451990         13.087967          2.987444
# Simulation            4.138218          4.681874          4.917414
# Sports               15.545970         15.539847         10.446806
# Strategy              1.557027          1.862934          3.827567

# %%
fig, axs = plt.subplots(2, 2, figsize=(29, 15))

axs[0, 0].bar(NA_pert_sales_genre.index, NA_pert_sales_genre.values, color = 'blue', alpha = 1)
axs[0, 0].set_title('North America')

axs[0, 1].bar(EU_pert_sales_genre.index, EU_pert_sales_genre.values, color = 'red', alpha = 1)
axs[0, 1].set_title('Europe')

axs[1, 0].bar(JP_pert_sales_genre.index, JP_pert_sales_genre.values, color = 'green', alpha = 1)
axs[1, 0].set_title('Japan')



for ax in axs.flat:
    ax.set(xlabel='Genre', ylabel='Percentage of Total Sales')

#for ax in axs.flat:
    #ax.label_outer()

ax.tick_params(axis='x', rotation=45)    
    
plt.show()

# %%
Yr = game_sales_df['Year_of_Release'].value_counts()

game_sales_df['Year_of_Release'].dtypes
# Out:
# dtype('float64')
